# %% [markdown]
# # Importing Data and Libraries

# %%
import sqlite3
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
con = sqlite3.connect('data/im.db')
cur = con.cursor()

# %%
bmg = pd.read_csv('data/bom.movie_gross.csv')
mb = pd.read_csv('data/tn.movie_budgets.csv')
m = pd.read_csv('data/tmdb.movies.csv')

# %%
rv = pd.read_csv('data/rt.reviews.tsv', delimiter = '\t', encoding = 'latin') 
# needed to change the encoding as it was throwing an error message about it
# tsv file, so needed to add a delimiter of tab

# %%
mi = pd.read_csv('data/rt.movie_info.tsv', delimiter = '\t')

# %%
imdb_rated = pd.read_csv('data/IMDB_rated_only.csv')

# %% [markdown]
# # Exploring the im.db Data

# %%
# %%bash
#
# sqlite3 data/im.db
# .tables
#
# #checking the table names
# Out:
# directors      movie_akas     movie_ratings  principals
# known_for      movie_basics   persons        writers

# %%
# %%bash
#
# sqlite3 data/im.db
# .schema
#
# #checking schema
# Out:
# CREATE TABLE IF NOT EXISTS "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# );
# CREATE TABLE IF NOT EXISTS "directors" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "known_for" (
# "person_id" TEXT,
#   "movie_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# );
# CREATE TABLE IF NOT EXISTS "movie_ratings" (
# "movie_id" TEXT,
#   "averagerating" REAL,
#   "numvotes" INTEGER
# );
# CREATE TABLE IF NOT EXISTS "persons" (
# "person_id" TEXT,
#   "primary_name" TEXT,
#   "birth_year" REAL,
#   "death_year" REAL,
#   "primary_profession" TEXT
# );
# CREATE TABLE IF NOT EXISTS "principals" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "person_id" TEXT,
#   "category" TEXT,
#   "job" TEXT,
#   "characters" TEXT
# );
# CREATE TABLE IF NOT EXISTS "writers" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );

# %%
query_result = pd.read_sql('''
    SELECT *
    FROM 
        movie_ratings AS mr 
        INNER JOIN movie_basics AS mb
            ON mb.movie_id = mr.movie_id
    
    ORDER BY "averagerating" DESC

    LIMIT 50
    
''', con)

query_result
# Out:
#       movie_id  averagerating  numvotes    movie_id  \
# 0    tt5390098           10.0         5   tt5390098
# 1    tt6295832           10.0         5   tt6295832
# 2    tt1770682           10.0         5   tt1770682
# 3    tt2632430           10.0         5   tt2632430
# 4    tt8730716           10.0         5   tt8730716
# 5    tt4960818           10.0         8   tt4960818
# 6    tt6991826           10.0         5   tt6991826
# 7   tt10176328           10.0         5  tt10176328
# 8    tt4944240           10.0         5   tt4944240
# 9    tt5089804           10.0         7   tt5089804
# 10   tt7259300           10.0         6   tt7259300
# 11  tt10378660           10.0         5  tt10378660
# 12   tt5344358           10.0         6   tt5344358
# 13   tt4109192           10.0         6   tt4109192
# 14   tt7227500           10.0         6   tt7227500
# 15   tt9715646           10.0        20   tt9715646
# 16   tt9743544            9.9         8   tt9743544
# 17   tt9747294            9.9         8   tt9747294
# 18   tt9820678            9.9        18   tt9820678
# 19   tt9866708            9.9        10   tt9866708
# 20   tt9537008            9.9       417   tt9537008
# 21   tt3450432            9.8         5   tt3450432
# 22   tt6961300            9.8         5   tt6961300
# 23   tt8986906            9.8        45   tt8986906
# 24  tt10177960            9.8         6  tt10177960
# 25   tt7724146            9.8         5   tt7724146
# 26   tt9880724            9.8        28   tt9880724
# 27   tt4818518            9.8         5   tt4818518
# 28   tt5012400            9.8         6   tt5012400
# 29  tt10404502            9.8         5  tt10404502
# 30   tt6271662            9.8         6   tt6271662
# 31   tt7813466            9.8         5   tt7813466
# 32   tt3862814            9.8         5   tt3862814
# 33   tt2357225            9.8         5   tt2357225
# 34   tt6143970            9.8        28   tt6143970
# 35   tt4023464            9.8        28   tt4023464
# 36   tt7541970            9.7         6   tt7541970
# 37  tt10146728            9.7        22  tt10146728
# 38   tt4824256            9.7         6   tt4824256
# 39   tt1740810            9.7        25   tt1740810
# 40   tt8118944            9.7        32   tt8118944
# 41   tt7414870            9.7        48   tt7414870
# 42   tt5160520            9.7         6   tt5160520
# 43   tt9787524            9.7        72   tt9787524
# 44  tt10121022            9.7         7  tt10121022
# 45   tt7131622            9.7      5600   tt7131622
# 46  tt10204276            9.7        30  tt10204276
# 47   tt8718580            9.7       639   tt8718580
# 48   tt9680166            9.6       624   tt9680166
# 49   tt8109740            9.6         8   tt8109740
#
#                                         primary_title  \
# 0                 The Paternal Bond: Barbary Macaques
# 1                               Requiem voor een Boom
# 2                                Freeing Bernie Baran
# 3                               Hercule contre Hermès
# 4                       Pick It Up! - Ska in the '90s
# 5                                     Revolution Food
# 6     A Dedicated Life: Phoebe Brand Beyond the Group
# 7      Exteriores: Mulheres Brasileiras na Diplomacia
# 8                           Dog Days in the Heartland
# 9                     Fly High: Story of the Disc Dog
# 10                                     Calamity Kevin
# 11          The Dark Knight: The Ballad of the N Word
# 12                                      All Around Us
# 13                              I Was Born Yesterday!
# 14  Ellis Island: The Making of a Master Race in A...
# 15                                           Renegade
# 16         The Wedding Present: Something Left Behind
# 17                                        LA Foodways
# 18                                Moscow we will lose
# 19                                     Wild Karnataka
# 20                                  Gini Helida Kathe
# 21                          Send My Mail to Nashville
# 22                                        Goreci skof
# 23                      RISE: The Story of Augustines
# 24                         Dreaming of a Vetter World
# 25            A Mediocre Documentary with Tom And Dan
# 26                                         Verdict 19
# 27                                       Hiro's Table
# 28                  Pieces of Lives, Pieces of Dreams
# 29  Grisaia: Phantom trigger the animation 02. Sou...
# 30                                              Hizam
# 31                                       Transhumance
# 32                   Maasai 10th Lost Tribe of Israel
# 33                               Mujeres republicanas
# 34                             La Lección de Anatomía
# 35                                     Our Friend Jon
# 36                                  From Shock to Awe
# 37                                        Foosballers
# 38                                          Blackbear
# 39                                    Love on a Leash
# 40                                     My Darling Son
# 41              MANRY AT SEA ~ In the Wake of a Dream
# 42  Silver Wings/Flying Dreams The Complete Story ...
# 43                                              DOSED
# 44                                        Freie Räume
# 45                  Once Upon a Time ... in Hollywood
# 46                              Soldiers Without Guns
# 47                                          Eghantham
# 48                          Yeh Suhaagraat Impossible
# 49                                            30 KM/H
#
#                                        original_title  start_year  \
# 0   Atlas Mountain: Barbary Macaques - Childcaring...        2015
# 1                               Requiem voor een Boom        2016
# 2                                Freeing Bernie Baran        2010
# 3                               Hercule contre Hermès        2012
# 4                       Pick It Up! - Ska in the '90s        2019
# 5                                     Revolution Food        2015
# 6     A Dedicated Life: Phoebe Brand Beyond the Group        2015
# 7      Exteriores: Mulheres Brasileiras na Diplomacia        2018
# 8                           Dog Days in the Heartland        2017
# 9                     Fly High: Story of the Disc Dog        2019
# 10                                     Calamity Kevin        2019
# 11          The Dark Knight: The Ballad of the N Word        2018
# 12                                      All Around Us        2019
# 13                              I Was Born Yesterday!        2015
# 14  Ellis Island: The Making of a Master Race in A...        2018
# 15                                           Renegade        2019
# 16         The Wedding Present: Something Left Behind        2018
# 17                                        LA Foodways        2019
# 18                                Moscow we will lose        2019
# 19                                     Wild Karnataka        2019
# 20                                  Gini Helida Kathe        2019
# 21                          Send My Mail to Nashville        2013
# 22                                        Goreci skof        2017
# 23                      RISE: The Story of Augustines        2018
# 24                         Dreaming of a Vetter World        2018
# 25            A Mediocre Documentary with Tom And Dan        2018
# 26                                         Verdict 19        2019
# 27                                       Hiro's Table        2018
# 28                  Pieces of Lives, Pieces of Dreams        2012
# 29  Grisaia: Phantom trigger the animation 02. Sou...        2019
# 30                                              Hizam        2016
# 31                                       Transhumance        2018
# 32                   Maasai 10th Lost Tribe of Israel        2014
# 33                               Mujeres republicanas        2010
# 34                             La Lección de Anatomía        2019
# 35                                     Our Friend Jon        2018
# 36                                  From Shock to Awe        2017
# 37                                        Foosballers        2019
# 38                                         Submission        2019
# 39                                    Love on a Leash        2010
# 40                                     My Darling Son        2018
# 41              MANRY AT SEA ~ In the Wake of a Dream        2018
# 42  Silver Wings/Flying Dreams The Complete Story ...        2015
# 43                                              DOSED        2019
# 44                                        Freie Räume        2019
# 45                  Once Upon a Time ... in Hollywood        2019
# 46                              Soldiers Without Guns        2019
# 47                                          Eghantham        2018
# 48                          Yeh Suhaagraat Impossible        2019
# 49                                            30 KM/H        2018
#
#     runtime_minutes                       genres
# 0              59.0                  Documentary
# 1              48.0                  Documentary
# 2             100.0            Crime,Documentary
# 3              72.0                  Documentary
# 4              99.0                  Documentary
# 5              70.0                  Documentary
# 6              93.0                  Documentary
# 7              52.0                  Documentary
# 8               NaN                        Drama
# 9              65.0                  Documentary
# 10             77.0             Adventure,Comedy
# 11            129.0                 Comedy,Drama
# 12              NaN                  Documentary
# 13             31.0                  Documentary
# 14             70.0          Documentary,History
# 15              NaN                  Documentary
# 16             87.0                  Documentary
# 17             56.0                  Documentary
# 18             51.0                  Documentary
# 19             53.0                  Documentary
# 20            138.0                        Drama
# 21             96.0  Biography,Documentary,Music
# 22             55.0                  Documentary
# 23             80.0            Documentary,Music
# 24             77.0                  Documentary
# 25             79.0           Comedy,Documentary
# 26              NaN  Biography,Documentary,Drama
# 27              NaN                  Documentary
# 28            100.0                  Documentary
# 29             54.0                       Action
# 30             86.0                  Documentary
# 31             52.0                  Documentary
# 32             61.0  Biography,Documentary,Drama
# 33             82.0                  Documentary
# 34              NaN                  Documentary
# 35              NaN                  Documentary
# 36             87.0              Documentary,War
# 37              NaN     Comedy,Documentary,Sport
# 38             94.0                  Drama,Sport
# 39             10.0   Documentary,Family,Romance
# 40             61.0                  Documentary
# 41             94.0                  Documentary
# 42             50.0  Biography,Documentary,Drama
# 43             82.0                  Documentary
# 44            102.0                  Documentary
# 45            159.0                 Comedy,Drama
# 46             92.0                  Documentary
# 47            125.0                        Drama
# 48             92.0                       Comedy
# 49             68.0        Adventure,Documentary

# %%
query_result = pd.read_sql('''
    SELECT DISTINCT *
    FROM directors, movie_akas, movie_ratings, principals,  
          known_for, movie_basics, persons, writers 
    LIMIT 5
''', con)

query_result
# Out:
#     movie_id  person_id   movie_id  ordering          title region language  \
# 0  tt0285252  nm0899854  tt0369610        10  Джурасик свят     BG       bg
# 1  tt0285252  nm0899854  tt0369610        10  Джурасик свят     BG       bg
# 2  tt0285252  nm0899854  tt0369610        10  Джурасик свят     BG       bg
# 3  tt0285252  nm0899854  tt0369610        10  Джурасик свят     BG       bg
# 4  tt0285252  nm0899854  tt0369610        10  Джурасик свят     BG       bg
#
#   types attributes  is_original_title  ... start_year  runtime_minutes  \
# 0  None       None                0.0  ...       2013            175.0
# 1  None       None                0.0  ...       2013            175.0
# 2  None       None                0.0  ...       2013            175.0
# 3  None       None                0.0  ...       2013            175.0
# 4  None       None                0.0  ...       2013            175.0
#
#                genres  person_id       primary_name birth_year death_year  \
# 0  Action,Crime,Drama  nm0061671  Mary Ellen Bauder       None       None
# 1  Action,Crime,Drama  nm0061671  Mary Ellen Bauder       None       None
# 2  Action,Crime,Drama  nm0061671  Mary Ellen Bauder       None       None
# 3  Action,Crime,Drama  nm0061671  Mary Ellen Bauder       None       None
# 4  Action,Crime,Drama  nm0061671  Mary Ellen Bauder       None       None
#
#                           primary_profession   movie_id  person_id
# 0  miscellaneous,production_manager,producer  tt0285252  nm0899854
# 1  miscellaneous,production_manager,producer  tt0438973  nm0175726
# 2  miscellaneous,production_manager,producer  tt0438973  nm1802864
# 3  miscellaneous,production_manager,producer  tt0462036  nm1940585
# 4  miscellaneous,production_manager,producer  tt0835418  nm0310087
#
# [5 rows x 34 columns]

# %%
con.close()

# %% [markdown]
# # Cleaning CSV files

# %%
bmg = bmg.reset_index()

# %%
bmg['foreign_gross'] = bmg['foreign_gross'].str.replace(',','')

# %%
bmg['foreign_gross'] = bmg['foreign_gross'].astype(float)

# %%
mb['domestic_gross'] = mb['domestic_gross'].str.replace('$','')
mb['domestic_gross'] = mb['domestic_gross'].str.replace(',','')
mb['domestic_gross'] = mb['domestic_gross'].astype(int)

# %%
mb['worldwide_gross'] = mb['worldwide_gross'].str.replace('$','')

# %%
mb['worldwide_gross'] = mb['worldwide_gross'].str.replace(',','')

# %%
mb['worldwide_gross'] = mb['worldwide_gross'].astype(int)

# %%
mb['foreign_gross'] = mb['worldwide_gross'] - mb['domestic_gross']

# %%
mb['release_date'] = pd.to_datetime(mb['release_date'])

# %%
mb['release_year'] = mb['release_date'].dt.year

# %%
m['release_date'] = pd.to_datetime(m['release_date'])

# %%
mb['release_year'] = mb['release_date'].dt.year

# %%
m['release_year'] = m['release_date'].dt.year

# %%
print(bmg['year'].dtype)
# Out:
# int64

# %% [markdown]
# # Exploring the Movie Gross file

# %%
bmg.info()
# looks like foreign_gross is a string when it should be an integer
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           3387 non-null   int64
#  1   title           3387 non-null   object
#  2   studio          3382 non-null   object
#  3   domestic_gross  3359 non-null   float64
#  4   foreign_gross   2037 non-null   float64
#  5   year            3387 non-null   int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 158.9+ KB

# %%
bmg.isna().sum()
#foreign gross has a ton of null values
# Out:
# index                0
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
mb.notna().sum()
# Out:
# id                   5782
# release_date         5782
# movie                5782
# production_budget    5782
# domestic_gross       5782
# worldwide_gross      5782
# foreign_gross        5782
# release_year         5782
# dtype: int64

# %% [markdown]
# # Exploring Movie Budgets file

# %%
mb.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget  domestic_gross  worldwide_gross  foreign_gross  \
# 0      $425,000,000       760507625       2776345279     2015837654
# 1      $410,600,000       241063875       1045663875      804600000
# 2      $350,000,000        42762350        149762350      107000000
# 3      $330,600,000       459005868       1403013963      944008095
# 4      $317,000,000       620181382       1316721747      696540365
#
#    release_year
# 0          2009
# 1          2011
# 2          2019
# 3          2015
# 4          2017

# %% [markdown]
# # Combining Data: bmg, mb, m

# %%
# tried this out mbm = m.merge(mb, how = 'left', left_on =['original_title', 'release_date'], right_on =['movie', 'release_date'])

# %%
#tried this out csvmerge = mbm.merge(bmg, how = 'left', left_on =['original_title', 'release_year'], right_on =['title', 'year'])

# %%
csvmerge =  m.merge(mb, how = 'left', 
                    left_on =['original_title', 'release_year'], 
                    right_on =['movie', 'release_year']).merge(bmg, how = 'left',
                                left_on =['original_title', 'release_year'], 
                                right_on =['title', 'year'])

# %%
#print(m.count())
#print(mb.count())
#print(bmg.count())
csvmerge.count()
#checking to see if merge worked ok and how many rows merged well together
# Out:
# Unnamed: 0           26517
# genre_ids            26517
# id_x                 26517
# original_language    26517
# original_title       26517
# popularity           26517
# release_date_x       26517
# title_x              26517
# vote_average         26517
# vote_count           26517
# release_year         26517
# id_y                  1759
# release_date_y        1759
# movie                 1759
# production_budget     1759
# domestic_gross_x      1759
# worldwide_gross       1759
# foreign_gross_x       1759
# index                 1985
# title_y               1985
# studio                1984
# domestic_gross_y      1975
# foreign_gross_y       1400
# year                  1985
# dtype: int64

# %%
csvmerge.tail(1)
# Out:
#        Unnamed: 0 genre_ids    id_x original_language original_title  \
# 26516       26516  [53, 27]  309885                en     The Church
#
#        popularity release_date_x     title_x  vote_average  vote_count  ...  \
# 26516         0.6     2018-10-05  The Church           0.0           1  ...
#
#        production_budget  domestic_gross_x worldwide_gross foreign_gross_x  \
# 26516                NaN               NaN             NaN             NaN
#
#       index  title_y  studio  domestic_gross_y  foreign_gross_y year
# 26516   NaN      NaN     NaN               NaN              NaN  NaN
#
# [1 rows x 24 columns]

# %%
print(bmg.columns)
print(csvmerge.columns)
csvmerge.info()
# Out:
# Index(['index', 'title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')
# Index(['Unnamed: 0', 'genre_ids', 'id_x', 'original_language',
#        'original_title', 'popularity', 'release_date_x', 'title_x',
#        'vote_average', 'vote_count', 'release_year', 'id_y', 'release_date_y',
#        'movie', 'production_budget', 'domestic_gross_x', 'worldwide_gross',
#        'foreign_gross_x', 'index', 'title_y', 'studio', 'domestic_gross_y',
#        'foreign_gross_y', 'year'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id_x               26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date_x     26517 non-null  datetime64[ns]
#  7   title_x            26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
#  10  release_year       26517 non-null  int64
#  11  id_y               1759 non-null   float64
#  12  release_date_y     1759 non-null   datetime64[ns]
#  13  movie              1759 non-null   object
#  14  production_budget  1759 non-null   object
#  15  domestic_gross_x   1759 non-null   float64
#  16  worldwide_gross    1759 non-null   float64
#  17  foreign_gross_x    1759 non-null   float64
#  18  index              1985 non-null   float64
#  19  title_y            1985 non-null   object
#  20  studio             1984 non-null   object
#  21  domestic_gross_y   1975 non-null   float64
#  22  foreign_gross_y    1400 non-null   float64
#  23  year               1985 non-null   float64
# dtypes: datetime64[ns](2), float64(10), int64(4), object(8)
# memory usage: 5.1+ MB

# %%
allcsvs_merged = imdb_rated.merge(csvmerge, how = 'left',
                 left_on = ['primary_title', 'start_year'], 
                 right_on = ['movie', 'release_year']).dropna().drop_duplicates(subset = ['movie','start_year'])

# %% [markdown]
# # Exploring Combined CSV tables

# %%
allcsvs_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 911 entries, 3 to 73243
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0_x       911 non-null    int64
#  1   movie_id           911 non-null    object
#  2   averagerating      911 non-null    float64
#  3   numvotes           911 non-null    int64
#  4   primary_title      911 non-null    object
#  5   original_title_x   911 non-null    object
#  6   start_year         911 non-null    int64
#  7   runtime_minutes    911 non-null    float64
#  8   genres             911 non-null    object
#  9   bin                911 non-null    object
#  10  Unnamed: 0_y       911 non-null    float64
#  11  genre_ids          911 non-null    object
#  12  id_x               911 non-null    float64
#  13  original_language  911 non-null    object
#  14  original_title_y   911 non-null    object
#  15  popularity         911 non-null    float64
#  16  release_date_x     911 non-null    datetime64[ns]
#  17  title_x            911 non-null    object
#  18  vote_average       911 non-null    float64
#  19  vote_count         911 non-null    float64
#  20  release_year       911 non-null    float64
#  21  id_y               911 non-null    float64
#  22  release_date_y     911 non-null    datetime64[ns]
#  23  movie              911 non-null    object
#  24  production_budget  911 non-null    object
#  25  domestic_gross_x   911 non-null    float64
#  26  worldwide_gross    911 non-null    float64
#  27  foreign_gross_x    911 non-null    float64
#  28  index              911 non-null    float64
#  29  title_y            911 non-null    object
#  30  studio             911 non-null    object
#  31  domestic_gross_y   911 non-null    float64
#  32  foreign_gross_y    911 non-null    float64
#  33  year               911 non-null    float64
# dtypes: datetime64[ns](2), float64(16), int64(3), object(13)
# memory usage: 249.1+ KB

# %%
allcsvs_merged.tail(1)
# Out:
#        Unnamed: 0_x   movie_id  averagerating  numvotes primary_title  \
# 73243         73118  tt2704998            7.0    163279    Game Night
#
#       original_title_x  start_year  runtime_minutes               genres  \
# 73243       Game Night        2018            100.0  Action,Comedy,Crime
#
#                bin  ...  production_budget domestic_gross_x  worldwide_gross  \
# 73243  (0, 300000]  ...        $37,000,000       69179066.0      117378084.0
#
#       foreign_gross_x   index     title_y   studio domestic_gross_y  \
# 73243      48199018.0  3133.0  Game Night  WB (NL)       69200000.0
#
#        foreign_gross_y    year
# 73243       48500000.0  2018.0
#
# [1 rows x 34 columns]

# %%
allcsvs_merged.shape
# Out:
# (911, 34)

# %%
allcsvs_merged.columns
# Out:
# Index(['Unnamed: 0_x', 'movie_id', 'averagerating', 'numvotes',
#        'primary_title', 'original_title_x', 'start_year', 'runtime_minutes',
#        'genres', 'bin', 'Unnamed: 0_y', 'genre_ids', 'id_x',
#        'original_language', 'original_title_y', 'popularity', 'release_date_x',
#        'title_x', 'vote_average', 'vote_count', 'release_year', 'id_y',
#        'release_date_y', 'movie', 'production_budget', 'domestic_gross_x',
#        'worldwide_gross', 'foreign_gross_x', 'index', 'title_y', 'studio',
#        'domestic_gross_y', 'foreign_gross_y', 'year'],
#       dtype='object')

# %%
allcsvs_merged.sort_values(by='worldwide_gross')
# Out:
#        Unnamed: 0_x   movie_id  averagerating  numvotes  \
# 1170           1168  tt1152822            6.4      6466
# 37757         37691  tt1274300            5.4      7073
# 8713           8702  tt1183923            7.0     22210
# 36171         36107  tt1361313            5.9      4580
# 67016         66905  tt2690138            5.0     10066
# ...             ...        ...            ...       ...
# 9044           9032  tt1825683            7.3    516148
# 66878         66768  tt2395427            7.3    665594
# 14229         14212  tt2820852            7.2    335074
# 7459           7450  tt0369610            7.0    539338
# 72001         71879  tt4154756            8.5    670926
#
#                  primary_title         original_title_x  start_year  \
# 1170              Freakonomics             Freakonomics        2010
# 37757              The Tempest              The Tempest        2010
# 8713     Welcome to the Rileys    Welcome to the Rileys        2010
# 36171            The Extra Man            The Extra Man        2010
# 67016              The D Train              The D Train        2015
# ...                        ...                      ...         ...
# 9044             Black Panther            Black Panther        2018
# 66878  Avengers: Age of Ultron  Avengers: Age of Ultron        2015
# 14229                Furious 7            Furious Seven        2015
# 7459            Jurassic World           Jurassic World        2015
# 72001   Avengers: Infinity War   Avengers: Infinity War        2018
#
#        runtime_minutes                   genres               bin  ...  \
# 1170              93.0              Documentary       (0, 300000]  ...
# 37757            110.0     Comedy,Drama,Fantasy       (0, 300000]  ...
# 8713             110.0                    Drama       (0, 300000]  ...
# 36171            108.0                   Comedy       (0, 300000]  ...
# 67016            101.0             Comedy,Drama       (0, 300000]  ...
# ...                ...                      ...               ...  ...
# 9044             134.0  Action,Adventure,Sci-Fi  (300000, 600000]  ...
# 66878            141.0  Action,Adventure,Sci-Fi  (600000, 900000]  ...
# 14229            137.0    Action,Crime,Thriller  (300000, 600000]  ...
# 7459             124.0  Action,Adventure,Sci-Fi  (300000, 600000]  ...
# 72001            149.0  Action,Adventure,Sci-Fi  (600000, 900000]  ...
#
#        production_budget domestic_gross_x  worldwide_gross foreign_gross_x  \
# 1170          $2,900,000         101270.0     1.728670e+05    7.159700e+04
# 37757        $20,000,000         277943.0     2.779430e+05    0.000000e+00
# 8713         $10,000,000         152857.0     3.559190e+05    2.030620e+05
# 36171         $7,000,000         453377.0     4.921080e+05    3.873100e+04
# 67016         $3,000,000         669688.0     7.723660e+05    1.026780e+05
# ...                  ...              ...              ...             ...
# 9044        $200,000,000      700059566.0     1.348258e+09    6.481987e+08
# 66878       $330,600,000      459005868.0     1.403014e+09    9.440081e+08
# 14229       $190,000,000      353007020.0     1.518723e+09    1.165716e+09
# 7459        $215,000,000      652270625.0     1.648855e+09    9.965842e+08
# 72001       $300,000,000      678815482.0     2.048134e+09    1.369319e+09
#
#         index                  title_y studio domestic_gross_y  \
# 1170    299.0             Freakonomics  Magn.         101000.0
# 37757   270.0              The Tempest  Mira.         278000.0
# 8713    274.0    Welcome to the Rileys  Gold.         159000.0
# 36171   266.0            The Extra Man  Magn.         453000.0
# 67016  2119.0              The D Train    IFC         673000.0
# ...       ...                      ...    ...              ...
# 9044   3080.0            Black Panther     BV      700100000.0
# 66878  1875.0  Avengers: Age of Ultron     BV      459000000.0
# 14229  1874.0                Furious 7   Uni.      353000000.0
# 7459   1873.0           Jurassic World   Uni.      652300000.0
# 72001  3079.0   Avengers: Infinity War     BV      678800000.0
#
#        foreign_gross_y    year
# 1170           16400.0  2010.0
# 37757          68700.0  2010.0
# 8713          158000.0  2010.0
# 36171           4500.0  2010.0
# 67016         102000.0  2015.0
# ...                ...     ...
# 9044       646900000.0  2018.0
# 66878      946400000.0  2015.0
# 14229           1163.0  2015.0
# 7459            1019.4  2015.0
# 72001           1369.5  2018.0
#
# [911 rows x 34 columns]

# %%
allcsvs_merged.sample(4)
# Out:
#        Unnamed: 0_x   movie_id  averagerating  numvotes  \
# 23952         23915  tt5664636            5.6     11459
# 61262         61161  tt2328900            6.3     23866
# 52133         52045  tt3614530            4.1      6683
# 55147         55053  tt2241351            6.5     86607
#
#                          primary_title                 original_title_x  \
# 23952  Goosebumps 2: Haunted Halloween  Goosebumps 2: Haunted Halloween
# 61262              Mary Queen of Scots              Mary Queen of Scots
# 52133            Jem and the Holograms            Jem and the Holograms
# 55147                    Money Monster                    Money Monster
#
#        start_year  runtime_minutes                   genres              bin  \
# 23952        2018             90.0  Adventure,Comedy,Family      (0, 300000]
# 61262        2018            124.0  Biography,Drama,History  (0.0, 300000.0]
# 52133        2015            118.0   Adventure,Drama,Family      (0, 300000]
# 55147        2016             98.0     Crime,Drama,Thriller      (0, 300000]
#
#        ...  production_budget domestic_gross_x  worldwide_gross  \
# 23952  ...        $35,000,000       46697321.0       93291478.0
# 61262  ...        $25,000,000       16468499.0       46734733.0
# 52133  ...         $5,000,000        2184640.0        2368937.0
# 55147  ...        $27,000,000       41012075.0       93466095.0
#
#       foreign_gross_x   index                          title_y studio  \
# 23952      46594157.0  3143.0  Goosebumps 2: Haunted Halloween   Sony
# 61262      30266234.0  3177.0              Mary Queen of Scots  Focus
# 52133        184297.0  2081.0            Jem and the Holograms   Uni.
# 55147      52454020.0  2402.0                    Money Monster   TriS
#
#       domestic_gross_y  foreign_gross_y    year
# 23952       46700000.0       46600000.0  2018.0
# 61262       16500000.0       29900000.0  2018.0
# 52133        2200000.0         149000.0  2015.0
# 55147       41000000.0       52300000.0  2016.0
#
# [4 rows x 34 columns]

# %%
pd.set_option('display.max_rows', None)
allcsvs_merged.sort_values(by='primary_title')
# Out:
#        Unnamed: 0_x   movie_id  averagerating  numvotes  \
# 1484           1481  tt1179933            7.2    260383
# 1534           1531  tt1413492            6.6     50155
# 20136         20104  tt2024544            8.1    577301
# 8823           8811  tt1542344            7.6    323949
# 71524         71403  tt1272878            6.7    182025
# 20               20  tt1232829            7.2    477771
# 32646         32590  tt2294449            7.0    319504
# 32554         32498  tt2172934            6.2     81681
# 15513         15491  tt1622547            6.1     87254
# 16167         16144  tt1335975            6.3    135754
# 56953         56857  tt1306980            7.7    300475
# 8592           8582  tt6359956            5.5     33056
# 60681         60580  tt1571222            6.4     93259
# 17419         17393  tt1606378            5.3    188383
# 65449         65342  tt2243537            5.1     40308
# 12900         12886  tt2828996            4.7     18085
# 67114         67002  tt2937898            7.0     60165
# 38199         38133  tt1972571            6.8     67914
# 72644         72520  tt6644200            7.6    305031
# 19376         19345  tt7040874            6.9     83338
# 45715         45644  tt0763831            5.9     36387
# 2230           2226  tt0365907            6.5    105116
# 3933           3929  tt1178665            6.3     22033
# 27935         27892  tt1620680            4.2     34888
# 17412         17386  tt1600195            5.1     72552
# 58308         58211  tt2194499            7.8    263136
# 891             890  tt1611224            5.9    142853
# 1609           1606  tt1591479            6.5     63787
# 24939         24901  tt6306064            6.6     34115
# 71824         71702  tt1815862            4.8    181687
# 44829         44758  tt2388637            6.4     19464
# 40860         40792  tt1712170            5.1     30951
# 69190         69074  tt1698641            6.2     37325
# 26168         26127  tt2567026            6.2     79951
# 49821         49739  tt2316204            6.4    226920
# 71506         71385  tt1175709            6.3     49684
# 72138         72014  tt4663548            6.0      1220
# 46649         46575  tt3640424            7.1    125741
# 53189         53098  tt4649416            6.1      5212
# 22               22  tt1243974            5.4     54646
# 64120         64015  tt4244998            6.7     41882
# 6085           6079  tt1615918            4.4     28158
# 38760         38694  tt2974918            5.1     14507
# 38196         38130  tt1961175            6.2     57793
# 46684         46609  tt3721936            7.0     31663
# 70168         70050  tt1800241            7.2    418221
# 31071         31019  tt3532216            7.2    131043
# 71637         71515  tt1605630            6.7    192250
# 4880           4875  tt2179136            7.3    401915
# 22088         22053  tt3316948            6.1     76769
# 67888         67774  tt1602620            7.9     84960
# 1180           1178  tt1229340            6.3    156116
# 55313         55219  tt2465146            5.8     11597
# 19692         19661  tt1313092            7.3     51576
# 6215           6209  tt1781769            6.6     84668
# 43138         43068  tt3322940            5.4    122039
# 3213           3209  tt1454029            8.1    392699
# 2241           2237  tt0903624            7.9    719629
# 66805         66695  tt2310332            7.4    438621
# 16136         16113  tt1170358            7.8    565563
# 34248         34190  tt4481514            5.6     33365
# 19044         19016  tt2980648            7.3     69562
# 63610         63506  tt1392170            7.2    795227
# 32407         32351  tt1951264            7.5    575455
# 51296         51213  tt1951265            6.6    379050
# 29013         28967  tt1951266            6.6    252384
# 27784         27742  tt1124035            7.1    207417
# 42495         42425  tt2084970            8.0    620834
# 17254         17230  tt0790628            5.9     67549
# 51616         51533  tt2361509            7.1    191494
# 42611         42541  tt2234155            6.3    179817
# 38140         38074  tt1872194            7.4    162952
# 1171           1169  tt1155076            6.2    146401
# 10628         10616  tt0842926            7.0    120656
# 21329         21295  tt0954947            6.1     31727
# 72687         72563  tt0938283            4.1    137734
# 15374         15352  tt1320244            5.6     45815
# 7501           7492  tt1294226            6.0     74914
# 52658         52569  tt1549920            6.4    126623
# 900             899  tt1618442            6.0     86118
# 29544         29495  tt2918436            5.2     37675
# 3                 3  tt1043726            4.2     50352
# 33971         33913  tt0918940            6.3    150154
# 66957         66846  tt2547584            7.2     46247
# 36134         36070  tt1189340            7.3    196109
# 40627         40559  tt1210819            6.4    208827
# 50035         49953  tt2726560            7.1     70327
# 54847         54753  tt0480255            6.4     83876
# 56963         56867  tt1327194            6.5     94359
# 16153         16130  tt1258972            5.4     58185
# 29846         29797  tt3659388            8.0    680116
# 19776         19745  tt1560747            7.1    131365
# 56080         55985  tt1790864            6.8    387038
# 24196         24158  tt0472399            6.6    141254
# 60070         59969  tt4779682            5.7    114042
# 20250         20218  tt2177771            6.1    117638
# 17374         17348  tt1538403            5.9    121936
# 66267         66157  tt7959026            7.1     58955
# 19673         19642  tt1204342            7.1     82752
# 16201         16178  tt1458175            7.4    168066
# 52921         52832  tt3799694            7.4    240337
# 19265         19235  tt3530002            6.4     58455
# 42745         42675  tt2402157            6.3     59293
# 34857         34799  tt1821658            5.7     24587
# 11498         11486  tt3486626            5.5      4820
# 47212         47136  tt5523010            5.5     18734
# 36122         36058  tt1041804            4.3      3119
# 27855         27812  tt1462769            6.6     42770
# 71548         71427  tt1386588            6.7    221664
# 57315         57219  tt3702652            5.3     15813
# 63638         63534  tt1496422            5.8     33940
# 35337         35276  tt2452042            7.1     39149
# 48763         48684  tt3862750            5.6      8998
# 26926         26884  tt4871980            4.9      3052
# 17454         17428  tt1659337            8.0    422671
# 54844         54750  tt0431021            5.9     53649
# 23969         23932  tt5734576            5.2     11629
# 18381         18354  tt6294822            7.2    108017
# 2455           2451  tt2184339            5.7    183549
# 61528         61427  tt2975578            6.5    126203
# 7990           7980  tt4094724            6.0     80254
# 1245           1243  tt1486192            6.4     79578
# 193             193  tt1663202            8.0    621193
# 60562         60461  tt1161864            6.0     85604
# 5950           5944  tt1265990            4.9     33062
# 66832         66722  tt2345737            6.4     40576
# 54843         54749  tt0376136            6.2     94787
# 2254           2250  tt1017451            6.6     43792
# 55355         55261  tt2555736            6.6     28931
# 51796         51710  tt2709768            6.5    161997
# 58039         57942  tt0359950            7.3    275300
# 4663           4658  tt1866249            7.2     39731
# 59837         59736  tt4052882            6.3    106927
# 15104         15083  tt5580390            7.3    308112
# 53274         53182  tt4971344            7.0     32135
# 55815         55721  tt1366344            5.7     65575
# 9834           9822  tt0472181            5.5     77577
# 39548         39480  tt2017020            5.4     34229
# 28073         28030  tt1758810            5.1     47890
# 53747         53654  tt1285016            7.7    568578
# 10634         10622  tt0963966            6.1    143862
# 17757         17731  tt3922818            6.4     41031
# 21681         21646  tt2279373            6.0     43560
# 3167           3163  tt1273678            5.5     36767
# 72116         71994  tt4587656            6.1      5159
# 70146         70028  tt0889573            6.1     90661
# 37757         37691  tt1274300            5.4      7073
# 62898         62797  tt2980516            7.7    361534
# 28953         28908  tt0383010            5.1     28570
# 56940         56844  tt1243957            6.0    206714
# 37715         37650  tt0840361            7.6    322524
# 50089         50007  tt2938956            5.2     36201
# 16120         16098  tt0478304            6.8    156266
# ...
# 4071        43900000.0        3200000.0  2011.0
# 42246       54700000.0       92600000.0  2011.0
# 42266       52400000.0       39500000.0  2015.0
# 51634      200100000.0      680600000.0  2015.0
# 30502      334200000.0      546000000.0  2017.0
# 28971       45100000.0       53200000.0  2015.0
# 13867       44100000.0       10700000.0  2014.0
# 36980      158800000.0      184600000.0  2016.0
# 53776      228800000.0      238600000.0  2013.0
# 17603       35100000.0      105400000.0  2012.0
# 35046       17800000.0       16700000.0  2015.0
# 67949        1700000.0       10400000.0  2013.0
# 69007        1800000.0        7700000.0  2010.0
# 34293       72700000.0      110700000.0  2016.0
# 17326      161200000.0       40400000.0  2015.0
# 47274        4200000.0        4200000.0  2017.0
# 44415       36400000.0       53400000.0  2011.0
# 58726        4700000.0       11300000.0  2015.0
# 27830      325100000.0      421700000.0  2016.0
# 19158      125100000.0      115700000.0  2016.0
# 6110       127000000.0      133100000.0  2011.0
# 72708        2500000.0        5400000.0  2018.0
# 55833        3600000.0        1400000.0  2017.0
# 21935       54700000.0       23400000.0  2018.0
# 25207        1700000.0        1400000.0  2011.0
# 32016      139900000.0      236300000.0  2012.0
# 55779       57700000.0       11300000.0  2010.0
# 21549       84500000.0       16000000.0  2014.0
# 9829       200800000.0      391000000.0  2010.0
# 71663      218800000.0      330600000.0  2012.0
# 36972       81500000.0      135200000.0  2015.0
# 21019       82100000.0      163600000.0  2016.0
# 7606        34300000.0       12900000.0  2013.0
# 52854       26100000.0       14400000.0  2014.0
# 63567       36900000.0       20800000.0  2012.0
# 8679        36300000.0       20800000.0  2018.0
# 41070       12200000.0       12700000.0  2015.0
# 70547       34900000.0       75000000.0  2016.0
# 51216       77200000.0      100000000.0  2010.0
# 49691       86300000.0       68900000.0  2016.0
# 53770       62500000.0       65400000.0  2011.0
# 59352       77600000.0      296400000.0  2011.0
# 60737       42600000.0       23000000.0  2015.0
# 2243       262000000.0      495900000.0  2012.0
# 28180      202900000.0      506100000.0  2014.0
# 16193       35600000.0       32299999.0  2010.0
# 34981      107500000.0      244800000.0  2016.0
# 55829      171200000.0       81000000.0  2010.0
# 3544        41400000.0       53900000.0  2018.0
# 16121        2500000.0        5900000.0  2017.0
# 54892       83000000.0      199500000.0  2013.0
# 3461       115600000.0       47800000.0  2014.0
# 3651        42500000.0        4200000.0  2018.0
# 14009       10200000.0        4200000.0  2015.0
# 60063        8900000.0        6300000.0  2018.0
# 7525        63700000.0       67099999.0  2011.0
# 59049        7700000.0        6600000.0  2018.0
# 9835        81600000.0       86200000.0  2010.0
# 66044       12000000.0        2400000.0  2018.0
# 52641       58900000.0       46000000.0  2015.0
# 27760      110500000.0      106000000.0  2010.0
# 4926        41200000.0      184700000.0  2017.0
# 15552       36700000.0       43900000.0  2010.0
# 32867        3300000.0         195000.0  2014.0
# 44004       47800000.0       28200000.0  2018.0
# 20102        5800000.0       28500000.0  2015.0
# 32155       17500000.0        4200000.0  2012.0
# 4770        43000000.0       43200000.0  2016.0
# 71615       79900000.0       97700000.0  2011.0
# 67303      146900000.0      343800000.0  2017.0
# 4625        47400000.0      386300000.0  2016.0
# 6059        66400000.0       50600000.0  2013.0
# 36155       13700000.0        9400000.0  2011.0
# 56917       58700000.0       58400000.0  2011.0
# 69374        3600000.0        7500000.0  2015.0
# 3980        75600000.0       44500000.0  2011.0
# 57170      150400000.0      119600000.0  2013.0
# 35645       10800000.0        2100000.0  2018.0
# 8713          159000.0         158000.0  2010.0
# 53858       41200000.0       43200000.0  2012.0
# 23366       14000000.0       16399999.0  2011.0
# 15385       29700000.0         911000.0  2016.0
# 32808       13100000.0       35900000.0  2014.0
# 59997       24000000.0        1900000.0  2018.0
# 29283       73100000.0      132300000.0  2013.0
# 14802       60300000.0       57800000.0  2016.0
# 54259       42400000.0       33600000.0  2018.0
# 1493          109000.0        3300000.0  2010.0
# 19725       26700000.0       23200000.0  2011.0
# 32017        6500000.0        7300000.0  2010.0
# 18995        3600000.0        1900000.0  2014.0
# 36877       33299999.0       28300000.0  2015.0
# 65652      132400000.0      173500000.0  2017.0
# 8697       412600000.0      409300000.0  2017.0
# 62230      202400000.0      337600000.0  2013.0
# 17445       83700000.0      221600000.0  2012.0
# 28081      189400000.0      281800000.0  2012.0
# 31015      155400000.0      388500000.0  2016.0
# 6318       233900000.0      513900000.0  2014.0
# 19681      146400000.0      207200000.0  2011.0
# 71528      100200000.0      101300000.0  2010.0
# 1222        25700000.0        6300000.0  2010.0
# 3147         3200000.0       31000000.0  2010.0
# 37896       16300000.0        6600000.0  2011.0
# 67769       21600000.0        3300000.0  2011.0
# 38061       95700000.0       37100000.0  2012.0
# 19675       80400000.0       89500000.0  2011.0
# 153         28800000.0       27900000.0  2016.0
# 30863      341300000.0      682500000.0  2016.0
#
# [911 rows x 34 columns]

# %%
pd.set_option('display.max_rows', 50)

# %%
allcsvs_merged.columns
# Out:
# Index(['Unnamed: 0_x', 'movie_id', 'averagerating', 'numvotes',
#        'primary_title', 'original_title_x', 'start_year', 'runtime_minutes',
#        'genres', 'bin', 'Unnamed: 0_y', 'genre_ids', 'id_x',
#        'original_language', 'original_title_y', 'popularity', 'release_date_x',
#        'title_x', 'vote_average', 'vote_count', 'release_year', 'id_y',
#        'release_date_y', 'movie', 'production_budget', 'domestic_gross_x',
#        'worldwide_gross', 'foreign_gross_x', 'index', 'title_y', 'studio',
#        'domestic_gross_y', 'foreign_gross_y', 'year'],
#       dtype='object')

# %% [markdown]
# # Cleaning the Merged Data

# %%
cleancm = allcsvs_merged[['title_x', 'genres', 'original_language', 'foreign_gross_x', 'foreign_gross_y', 'worldwide_gross', 
                     'release_date_x', 'domestic_gross_x', 'domestic_gross_y', 
                     'production_budget', 'popularity', 'vote_average',
                     'vote_count', 'release_year', 'id_y', 'release_date_y',
                       'studio',
                      'averagerating', 'numvotes',
                       'runtime_minutes', ]]
cleancm.head()
# Out:
#                    title_x                    genres original_language  \
# 3   The Legend of Hercules  Action,Adventure,Fantasy                en
# 10           Baggage Claim                    Comedy                en
# 16               Moneyball     Biography,Drama,Sport                en
# 17               Hereafter     Drama,Fantasy,Romance                en
# 20          21 Jump Street       Action,Comedy,Crime                en
#
#     foreign_gross_x  foreign_gross_y  worldwide_gross release_date_x  \
# 3        40104781.0       42400000.0       58953319.0     2014-01-10
# 10        1316327.0         887000.0       22885836.0     2013-09-27
# 16       35695343.0       34600000.0      111300835.0     2011-09-22
# 17       75913329.0       72500000.0      108660270.0     2010-10-22
# 20       64364762.0       63100000.0      202812429.0     2012-03-12
#
#     domestic_gross_x  domestic_gross_y production_budget  popularity  \
# 3         18848538.0        18800000.0       $70,000,000      13.754
# 10        21569509.0        21600000.0        $8,500,000       8.666
# 16        75605492.0        75600000.0       $50,000,000      15.393
# 17        32746941.0        32700000.0       $50,000,000       7.886
# 20       138447667.0       138400000.0       $42,000,000      14.836
#
#     vote_average  vote_count  release_year  id_y release_date_y studio  \
# 3            4.5       805.0        2014.0  42.0     2014-01-10   LG/S
# 10           5.4       127.0        2013.0  38.0     2013-09-27   FoxS
# 16           7.1      2255.0        2011.0  15.0     2011-09-23   Sony
# 17           5.9       848.0        2010.0  61.0     2010-10-15     WB
# 20           6.8      6527.0        2012.0  44.0     2012-03-16   Sony
#
#     averagerating  numvotes  runtime_minutes
# 3             4.2     50352             99.0
# 10            5.1      8296             96.0
# 16            7.6    326657            133.0
# 17            6.5     87288            129.0
# 20            7.2    477771            109.0

# %%
cleancm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 911 entries, 3 to 73243
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title_x            911 non-null    object
#  1   genres             911 non-null    object
#  2   original_language  911 non-null    object
#  3   foreign_gross_x    911 non-null    float64
#  4   foreign_gross_y    911 non-null    float64
#  5   worldwide_gross    911 non-null    float64
#  6   release_date_x     911 non-null    datetime64[ns]
#  7   domestic_gross_x   911 non-null    float64
#  8   domestic_gross_y   911 non-null    float64
#  9   production_budget  911 non-null    object
#  10  popularity         911 non-null    float64
#  11  vote_average       911 non-null    float64
#  12  vote_count         911 non-null    float64
#  13  release_year       911 non-null    float64
#  14  id_y               911 non-null    float64
#  15  release_date_y     911 non-null    datetime64[ns]
#  16  studio             911 non-null    object
#  17  averagerating      911 non-null    float64
#  18  numvotes           911 non-null    int64
#  19  runtime_minutes    911 non-null    float64
# dtypes: datetime64[ns](2), float64(12), int64(1), object(5)
# memory usage: 149.5+ KB

# %%
cleancm.sort_values(by='foreign_gross_x', ascending=True).head(20)
#cleancm.sort_values(by='foreign_gross_y', ascending=True).head(20)

# compared foreign_gross_x values with foreign_gross_y values
# looks like there is some bad data in both
# Seems like there is less bad data in is foreign_gross_x
# need to drop two rows of bad data in it, and use foreign_gross_x for visualizations
# Out:
#                           title_x                  genres original_language  \
# 67902              Shark Night 3D         Horror,Thriller                en
# 37757                 The Tempest    Comedy,Drama,Fantasy                en
# 36171               The Extra Man                  Comedy                en
# 1170                 Freakonomics             Documentary                en
# 41478  Kevin Hart: Let Me Explain      Comedy,Documentary                en
# 67016                 The D Train            Comedy,Drama                en
# 5999                    MacGruber   Action,Comedy,Romance                en
# 72138                  All Saints                   Drama                en
# 32867               Veronica Mars     Crime,Drama,Mystery                en
# 52133       Jem and the Holograms  Adventure,Drama,Family                en
# 8713        Welcome to the Rileys                   Drama                en
# 63796                Joyful Noise      Comedy,Drama,Music                en
# 19671                 Casino Jack  Biography,Comedy,Crime                en
# 25046              Black Nativity      Drama,Family,Music                en
# 21318  It's Kind of a Funny Story    Comedy,Drama,Romance                en
# 52595           For Colored Girls                   Drama                en
# 71506             All Good Things     Crime,Drama,Mystery                en
# 37783                 Just Wright    Comedy,Romance,Sport                en
# 17554                  Like Crazy           Drama,Romance                en
# 11547    Barbershop: The Next Cut            Comedy,Drama                en
#
#        foreign_gross_x  foreign_gross_y  worldwide_gross release_date_x  \
# 67902              0.0       21300000.0       18877153.0     2011-09-02
# 37757              0.0          68700.0         277943.0     2010-12-10
# 36171          38731.0           4500.0         492108.0     2010-08-01
# 1170           71597.0          16400.0         172867.0     2010-10-01
# 41478          83204.0          74000.0       32327255.0     2013-07-03
# 67016         102678.0         102000.0         772366.0     2015-05-08
# 5999          104295.0         797000.0        8629895.0     2010-05-21
# 72138         139786.0         140000.0        5941994.0     2017-08-25
# 32867         163256.0         195000.0        3485383.0     2014-03-14
# 52133         184297.0         149000.0        2368937.0     2015-10-23
# 8713          203062.0         158000.0         355919.0     2010-10-29
# 63796         225801.0         226000.0       31157914.0     2012-01-13
# 19671         232317.0          40700.0        2272186.0     2010-12-17
# 25046         266947.0         436000.0        7285135.0     2013-11-27
# 21318         269322.0         128000.0        6632950.0     2010-10-08
# 52595         288175.0          17300.0       38017873.0     2010-11-05
# 71506         291593.0          62500.0         873617.0     2010-12-03
# 37783         327302.0          29900.0       21867665.0     2010-05-14
# 17554         333009.0         336000.0        3728400.0     2011-10-28
# 11547         374151.0        1000000.0       54404202.0     2016-04-15
#
#        domestic_gross_x  domestic_gross_y production_budget  popularity  \
# 67902        18877153.0        18900000.0       $25,000,000       7.879
# 37757          277943.0          278000.0       $20,000,000       6.300
# 36171          453377.0          453000.0        $7,000,000       5.056
# 1170           101270.0          101000.0        $2,900,000       5.705
# 41478        32244051.0        32200000.0        $2,500,000       8.476
# 67016          669688.0          673000.0        $3,000,000       6.465
# 5999          8525600.0         8500000.0       $10,000,000       7.666
# 72138         5802208.0         5800000.0        $2,000,000       4.042
# 32867         3322127.0         3300000.0        $6,000,000       7.821
# 52133         2184640.0         2200000.0        $5,000,000       7.942
# 8713           152857.0          159000.0       $10,000,000       8.348
# 63796        30932113.0        30900000.0       $27,500,000       6.787
# 19671         2039869.0         1000000.0       $12,500,000       9.432
# 25046         7018188.0         7000000.0       $17,500,000       1.779
# 21318         6363628.0         6400000.0        $8,000,000      10.010
# 52595        37729698.0        37700000.0       $21,000,000       2.858
# 71506          582024.0          582000.0       $20,000,000       7.871
# 37783        21540363.0        21500000.0       $12,000,000       7.047
# 17554         3395391.0         3400000.0          $250,000      10.091
# 11547        54030051.0        54000000.0       $20,000,000      12.846
#
#        vote_average  vote_count  release_year  id_y release_date_y   studio  \
# 67902           5.0       245.0        2011.0  52.0     2011-09-02    Rela.
# 37757           5.8        52.0        2010.0   1.0     2010-12-10    Mira.
# 36171           5.9        46.0        2010.0  53.0     2010-07-30    Magn.
# 1170            6.6        57.0        2010.0  80.0     2010-10-01    Magn.
# 41478           6.9       142.0        2013.0  14.0     2013-07-03     LG/S
# 67016           4.6       125.0        2015.0  34.0     2015-05-08      IFC
# 5999            5.3       270.0        2010.0  42.0     2010-05-21     Uni.
# 72138           6.1        25.0        2017.0  12.0     2017-08-25   Affirm
# 32867           6.7       699.0        2014.0  63.0     2014-03-14       WB
# 52133           5.4       241.0        2015.0  53.0     2015-10-23     Uni.
# 8713            6.5       241.0        2010.0  12.0     2010-10-29    Gold.
# 63796           6.4        70.0        2012.0  86.0     2012-01-13       WB
# 19671           6.1       149.0        2010.0  32.0     2010-12-17      ATO
# 25046           5.7        25.0        2013.0  63.0     2013-11-27     FoxS
# 21318           7.0      1324.0        2010.0   1.0     2010-10-08    Focus
# 52595           6.8        33.0        2010.0  67.0     2010-11-05      LGF
# 71506           6.0       493.0        2010.0  96.0     2010-12-03    Magn.
# 37783           6.2       211.0        2010.0  85.0     2010-05-14     FoxS
# 17554           6.5       638.0        2011.0  74.0     2011-10-28     ParV
# 11547           6.0       248.0        2016.0  22.0     2016-04-15  WB (NL)
#
#        averagerating  numvotes  runtime_minutes
# 67902            4.0     23190             90.0
# 37757            5.4      7073            110.0
# 36171            5.9      4580            108.0
# 1170             6.4      6466             93.0
# 41478            6.8      7880             75.0
# 67016            5.0     10066            101.0
# 5999             5.5     39782             90.0
# 72138            6.0      1220            108.0
# 32867            6.8     46751            107.0
# 52133            4.1      6683            118.0
# 8713             7.0     22210            110.0
# 63796            5.8      7575            118.0
# 19671            6.2     16191            108.0
# 25046            4.6      1901             93.0
# 21318            7.1    125583            101.0
# 52595            6.1      6728            133.0
# 71506            6.3     49684            101.0
# 37783            5.9     12466            100.0
# 17554            6.7     55841             86.0
# 11547            5.9     13306            111.0

# %%
cleancm = cleancm.drop([67902, 37757])

# %%
cleancm.sort_values(by='foreign_gross_x', ascending=False).head(20)
# Out:
#                                            title_x  \
# 72001                       Avengers: Infinity War
# 14229                                    Furious 7
# 28455                      The Fate of the Furious
# 7459                                Jurassic World
# 66878                      Avengers: Age of Ultron
# 8196                Jurassic World: Fallen Kingdom
# 61218                                       Frozen
# 38300              Transformers: Age of Extinction
# 41299                                      Minions
# 52617                                      Aquaman
# 25018                                   Iron Man 3
# 56918                                      Skyfall
# 1502   Pirates of the Caribbean: On Stranger Tides
# 56986               Transformers: Dark of the Moon
# 31049                              Despicable Me 3
# 63102                   Captain America: Civil War
# 17461                   Ice Age: Continental Drift
# 2241             The Hobbit: An Unexpected Journey
# 16136          The Hobbit: The Desolation of Smaug
# 66805    The Hobbit: The Battle of the Five Armies
#
#                            genres original_language  foreign_gross_x  \
# 72001     Action,Adventure,Sci-Fi                en     1.369319e+09
# 14229       Action,Crime,Thriller                en     1.165716e+09
# 28455       Action,Crime,Thriller                en     1.009082e+09
# 7459      Action,Adventure,Sci-Fi                en     9.965842e+08
# 66878     Action,Adventure,Sci-Fi                en     9.440081e+08
# 8196      Action,Adventure,Sci-Fi                en     8.880530e+08
# 61218  Adventure,Animation,Comedy                en     8.717319e+08
# 38300     Action,Adventure,Sci-Fi                en     8.586000e+08
# 41299  Adventure,Animation,Comedy                en     8.242904e+08
# 52617    Action,Adventure,Fantasy                en     8.118328e+08
# 25018     Action,Adventure,Sci-Fi                en     8.064000e+08
# 56918   Action,Adventure,Thriller                en     8.061667e+08
# 1502     Action,Adventure,Fantasy                en     8.046000e+08
# 56986     Action,Adventure,Sci-Fi                en     7.714000e+08
# 31049  Adventure,Animation,Comedy                en     7.701034e+08
# 63102     Action,Adventure,Sci-Fi                en     7.319851e+08
# 17461  Adventure,Animation,Comedy                en     7.184433e+08
# 2241     Adventure,Family,Fantasy                en     7.140000e+08
# 16136           Adventure,Fantasy                en     7.020000e+08
# 66805           Adventure,Fantasy                en     6.904578e+08
#
#        foreign_gross_y  worldwide_gross release_date_x  domestic_gross_x  \
# 72001           1369.5     2.048134e+09     2018-04-27       678815482.0
# 14229           1163.0     1.518723e+09     2015-04-03       353007020.0
# 28455           1010.0     1.234846e+09     2017-04-14       225764765.0
# 7459            1019.4     1.648855e+09     2015-06-12       652270625.0
# 66878      946400000.0     1.403014e+09     2015-05-01       459005868.0
# 8196       891800000.0     1.305773e+09     2018-06-22       417719760.0
# 61218      875700000.0     1.272470e+09     2013-11-27       400738009.0
# 38300      858600000.0     1.104039e+09     2014-06-27       245439076.0
# 41299      823400000.0     1.160336e+09     2015-07-10       336045770.0
# 52617      812700000.0     1.146895e+09     2018-12-21       335061807.0
# 25018      805800000.0     1.215392e+09     2013-05-03       408992272.0
# 56918      804200000.0     1.110527e+09     2012-11-09       304360277.0
# 1502       804600000.0     1.045664e+09     2011-05-20       241063875.0
# 56986      771400000.0     1.123791e+09     2011-06-28       352390543.0
# 31049      770200000.0     1.034728e+09     2017-06-30       264624300.0
# 63102      745200000.0     1.140069e+09     2016-05-06       408084349.0
# 17461      715900000.0     8.797651e+08     2012-07-13       161321843.0
# 2241       718100000.0     1.017004e+09     2012-12-14       303003568.0
# 16136      700000000.0     9.603669e+08     2013-12-13       258366855.0
# 66805      700900000.0     9.455776e+08     2014-12-17       255119788.0
#
#        domestic_gross_y production_budget  popularity  vote_average  \
# 72001       678800000.0      $300,000,000      80.773           8.3
# 14229       353000000.0      $190,000,000      20.396           7.3
# 28455       226000000.0      $250,000,000      28.668           6.9
# 7459        652300000.0      $215,000,000      20.709           6.6
# 66878       459000000.0      $330,600,000      44.383           7.3
# 8196        417700000.0      $170,000,000      34.958           6.5
# 61218       400700000.0      $150,000,000      26.183           7.3
# 38300       245400000.0      $210,000,000      20.961           5.8
# 41299       336000000.0       $74,000,000       9.338           6.4
# 52617       335100000.0      $160,000,000      38.102           6.8
# 25018       409000000.0      $200,000,000      32.093           6.9
# 56918       304400000.0      $200,000,000      19.270           7.1
# 1502        241100000.0      $410,600,000      30.579           6.4
# 56986       352400000.0      $195,000,000       5.339           6.1
# 31049       264600000.0       $75,000,000      16.407           6.3
# 63102       408100000.0      $250,000,000      39.137           7.4
# 17461       161300000.0       $95,000,000      17.537           6.3
# 2241        303000000.0      $250,000,000      26.939           7.2
# 16136       258399999.0      $250,000,000      21.275           7.6
# 66805       255100000.0      $250,000,000      53.783           7.3
#
#        vote_count  release_year  id_y release_date_y   studio  averagerating  \
# 72001     13948.0        2018.0   7.0     2018-04-27       BV            8.5
# 14229      6538.0        2015.0  67.0     2015-04-03     Uni.            7.2
# 28455      6335.0        2017.0  23.0     2017-04-14     Uni.            6.7
# 7459      14056.0        2015.0  34.0     2015-06-12     Uni.            7.0
# 66878     13457.0        2015.0   4.0     2015-05-01       BV            7.3
# 8196       5995.0        2018.0  13.0     2018-06-22     Uni.            6.2
# 61218      9767.0        2013.0  56.0     2013-11-22       BV            7.5
# 38300      4805.0        2014.0  37.0     2014-06-27     Par.            5.7
# 41299      7343.0        2015.0  73.0     2015-07-10     Uni.            6.4
# 52617      6155.0        2018.0  36.0     2018-12-21       WB            7.1
# 25018     14155.0        2013.0  48.0     2013-05-03       BV            7.2
# 56918     10441.0        2012.0  52.0     2012-11-08     Sony            7.8
# 1502       8571.0        2011.0   2.0     2011-05-20       BV            6.6
# 56986      4961.0        2011.0  64.0     2011-06-29     P/DW            6.2
# 31049      4106.0        2017.0  30.0     2017-06-30     Uni.            6.3
# 63102     14000.0        2016.0  17.0     2016-05-06       BV            7.8
# 17461      4598.0        2012.0  14.0     2012-07-13      Fox            6.6
# 2241      12076.0        2012.0  19.0     2012-12-14  WB (NL)            7.9
# 16136      7739.0        2013.0  21.0     2013-12-13  WB (NL)            7.8
# 66805      8392.0        2014.0  22.0     2014-12-17  WB (NL)            7.4
#
#        numvotes  runtime_minutes
# 72001    670926            149.0
# 14229    335074            137.0
# 28455    179774            136.0
# 7459     539338            124.0
# 66878    665594            141.0
# 8196     219125            128.0
# 61218    516998            102.0
# 38300    283486            165.0
# 41299    193917             91.0
# 52617    263328            143.0
# 25018    692794            130.0
# 56918    592221            143.0
# 1502     447624            136.0
# 56986    366409            154.0
# 31049     92580             89.0
# 63102    583507            147.0
# 17461    175601             88.0
# 2241     719629            169.0
# 16136    565563            161.0
# 66805    438621            144.0

# %% [markdown]
# ## Making Merged DataFrame into CSV

# %%
cleancm.to_csv('/Users/jamiecarnevale/Documents/Flatiron/Projects/Phase 1/Movie_Production_Recommendations/Jamie/data/CSV_DB_Merge_V2.csv')

# %% [markdown]
# # Further Cleaning Merged DataFrame
# - This will help me explore the data more efficiently

# %%
df = cleancm[['title_x', 'genres', 'original_language', 'production_budget', 'worldwide_gross', 
                     'averagerating', 'release_date_x', 'domestic_gross_x', 'foreign_gross_x',
                      'popularity', 'vote_average', 'runtime_minutes',
                     'vote_count', 'release_year', 'studio', 'numvotes',
                        ]]

# %%
df = df.rename(columns={'title_x':'Title', 'genres': 'Genres', 'original_language':'OL', 
                   'production_budget': 'PBudget', 'worldwide_gross':'WWGross', 
                     'averagerating':'AvRating', 'release_date_x':'RDate', 
                   'domestic_gross_x':'DGrossX', 'foreign_gross_x':'FGrossX',
                      'popularity':'Pop', 'vote_average':'VoteAv', 'runtime_minutes':'RuntimeMin',
                     'vote_count':'VoteCount', 'release_year':'RelYear', 'studio':'Studio', 'numvotes':'NumVotes'})

# %%
df['PBudget'] = df['PBudget'].str.replace('$','')
df['PBudget'] = df['PBudget'].str.replace(',','')
df['PBudget'] = df['PBudget'].astype(int)

# %%
df['Profit'] =  df['WWGross'] - df['PBudget']

# %%
df = df[['Title', 'Genres', 'OL', 
                   'PBudget', 'WWGross', 'Profit',
                     'AvRating', 'RDate', 
                   'DGrossX', 'FGrossX',
                      'Pop', 'VoteAv', 'RuntimeMin',
                     'VoteCount', 'RelYear', 'Studio', 'NumVotes']]

# %%
df['IsProfitable'] = df['Profit'] > 0

# %%
df.sort_values(by='Profit', ascending=False).tail(10)
# Out:
#                                   Title                      Genres  OL  \
# 63553                      The Big Year                      Comedy  en
# 7870                  Deepwater Horizon        Action,Drama,History  en
# 37731                 The Warrior's Way      Action,Fantasy,Western  en
# 34971  King Arthur: Legend of the Sword      Action,Adventure,Drama  en
# 5928                          Jonah Hex        Action,Drama,Fantasy  en
# 17268                          Child 44         Crime,Drama,History  en
# 58587                          Blackhat       Action,Crime,Thriller  en
# 17255                          R.I.P.D.     Action,Adventure,Comedy  en
# 36122              The Nutcracker in 3D       Action,Family,Fantasy  en
# 3956                    Mars Needs Moms  Adventure,Animation,Family  en
#
#          PBudget      WWGross       Profit  AvRating      RDate     DGrossX  \
# 63553   41000000    7684524.0  -33315476.0       6.2 2011-10-14   7204138.0
# 7870   156000000  122603824.0  -33396176.0       7.1 2016-09-30  61433527.0
# 37731   42000000    8514325.0  -33485675.0       6.3 2010-12-03   5666340.0
# 34971  175000000  139630336.0  -35369664.0       6.8 2017-05-12  39175066.0
# 5928    47000000   11022696.0  -35977304.0       4.7 2010-06-18  10547117.0
# 17268   50000000    8004221.0  -41995779.0       6.5 2015-04-17   1224330.0
# 58587   70000000   19665004.0  -50334996.0       5.4 2015-01-16   8005980.0
# 17255  130000000   79076678.0  -50923322.0       5.6 2013-07-19  33618855.0
# 36122   90000000   20466016.0  -69533984.0       4.3 2010-11-24    195459.0
# 3956   150000000   39549758.0 -110450242.0       5.4 2011-03-11  21392758.0
#
#            FGrossX     Pop  VoteAv  RuntimeMin  VoteCount  RelYear Studio  \
# 63553     480386.0   7.077     5.8       100.0      393.0   2011.0    Fox
# 7870    61170297.0  13.685     6.7       107.0     2606.0   2016.0   LG/S
# 37731    2847985.0   8.259     6.1       100.0      203.0   2010.0  Rela.
# 34971  100455270.0  21.793     6.5       126.0     3305.0   2017.0     WB
# 5928      475579.0  13.467     4.6        81.0      708.0   2010.0     WB
# 17268    6779891.0  26.386     6.2       137.0      903.0   2015.0   LG/S
# 58587   11659024.0  16.824     5.3       133.0     1165.0   2015.0   Uni.
# 17255   45457823.0  21.377     5.6        96.0     2047.0   2013.0   Uni.
# 36122   20270557.0   7.566     5.5       110.0       97.0   2010.0   Free
# 3956    18157000.0   8.852     5.7        88.0      299.0   2011.0     BV
#
#        NumVotes  IsProfitable
# 63553     39522         False
# 7870     133303         False
# 37731     24271         False
# 34971    169054         False
# 5928      51860         False
# 17268     59477         False
# 58587     48427         False
# 17255    109078         False
# 36122      3119         False
# 3956      19823         False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 909 entries, 3 to 73243
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         909 non-null    object
#  1   Genres        909 non-null    object
#  2   OL            909 non-null    object
#  3   PBudget       909 non-null    int64
#  4   WWGross       909 non-null    float64
#  5   Profit        909 non-null    float64
#  6   AvRating      909 non-null    float64
#  7   RDate         909 non-null    datetime64[ns]
#  8   DGrossX       909 non-null    float64
#  9   FGrossX       909 non-null    float64
#  10  Pop           909 non-null    float64
#  11  VoteAv        909 non-null    float64
#  12  RuntimeMin    909 non-null    float64
#  13  VoteCount     909 non-null    float64
#  14  RelYear       909 non-null    float64
#  15  Studio        909 non-null    object
#  16  NumVotes      909 non-null    int64
#  17  IsProfitable  909 non-null    bool
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(2), object(4)
# memory usage: 128.7+ KB

# %%
df
# Out:
#                                      Title                      Genres  OL  \
# 3                   The Legend of Hercules    Action,Adventure,Fantasy  en
# 10                           Baggage Claim                      Comedy  en
# 16                               Moneyball       Biography,Drama,Sport  en
# 17                               Hereafter       Drama,Fantasy,Romance  en
# 20                          21 Jump Street         Action,Comedy,Crime  en
# ...                                    ...                         ...  ..
# 72774  Cloudy with a Chance of Meatballs 2  Adventure,Animation,Comedy  en
# 72883          Beasts of the Southern Wild     Adventure,Drama,Fantasy  en
# 73038                    The Expendables 3   Action,Adventure,Thriller  en
# 73039                             Snatched     Action,Adventure,Comedy  en
# 73243                           Game Night         Action,Comedy,Crime  en
#
#          PBudget      WWGross       Profit  AvRating      RDate      DGrossX  \
# 3       70000000   58953319.0  -11046681.0       4.2 2014-01-10   18848538.0
# 10       8500000   22885836.0   14385836.0       5.1 2013-09-27   21569509.0
# 16      50000000  111300835.0   61300835.0       7.6 2011-09-22   75605492.0
# 17      50000000  108660270.0   58660270.0       6.5 2010-10-22   32746941.0
# 20      42000000  202812429.0  160812429.0       7.2 2012-03-12  138447667.0
# ...          ...          ...          ...       ...        ...          ...
# 72774   78000000  274392649.0  196392649.0       6.4 2013-09-27  119793567.0
# 72883    1800000   23265132.0   21465132.0       7.3 2012-06-29   12795746.0
# 73038  100000000  209461378.0  109461378.0       6.1 2014-08-15   39322544.0
# 73039   42000000   57852177.0   15852177.0       4.5 2017-05-12   45852178.0
# 73243   37000000  117378084.0   80378084.0       7.0 2018-02-23   69179066.0
#
#            FGrossX     Pop  VoteAv  RuntimeMin  VoteCount  RelYear   Studio  \
# 3       40104781.0  13.754     4.5        99.0      805.0   2014.0     LG/S
# 10       1316327.0   8.666     5.4        96.0      127.0   2013.0     FoxS
# 16      35695343.0  15.393     7.1       133.0     2255.0   2011.0     Sony
# 17      75913329.0   7.886     5.9       129.0      848.0   2010.0       WB
# 20      64364762.0  14.836     6.8       109.0     6527.0   2012.0     Sony
# ...            ...     ...     ...         ...        ...      ...      ...
# 72774  154599082.0  18.335     6.4        95.0     1679.0   2013.0     Sony
# 72883   10469386.0   7.530     6.9        93.0      605.0   2012.0     FoxS
# 73038  170138834.0  18.797     6.1       126.0     2876.0   2014.0      LGF
# 73039   11999999.0  10.920     5.3        90.0      495.0   2017.0      Fox
# 73243   48199018.0  19.459     6.9       100.0     2756.0   2018.0  WB (NL)
#
#        NumVotes  IsProfitable
# 3         50352         False
# 10         8296          True
# 16       326657          True
# 17        87288          True
# 20       477771          True
# ...         ...           ...
# 72774     81010          True
# 72883     77440          True
# 73038    156432          True
# 73039     29997          True
# 73243    163279          True
#
# [909 rows x 18 columns]

# %%
dfexplode = df.copy()
dfexplode['Genres'] = df['Genres'].str.split(',')
dfexplode = dfexplode.explode('Genres')
dfexplode
# Out:
#                         Title     Genres  OL   PBudget      WWGross  \
# 3      The Legend of Hercules     Action  en  70000000   58953319.0
# 3      The Legend of Hercules  Adventure  en  70000000   58953319.0
# 3      The Legend of Hercules    Fantasy  en  70000000   58953319.0
# 10              Baggage Claim     Comedy  en   8500000   22885836.0
# 16                  Moneyball  Biography  en  50000000  111300835.0
# ...                       ...        ...  ..       ...          ...
# 73039                Snatched  Adventure  en  42000000   57852177.0
# 73039                Snatched     Comedy  en  42000000   57852177.0
# 73243              Game Night     Action  en  37000000  117378084.0
# 73243              Game Night     Comedy  en  37000000  117378084.0
# 73243              Game Night      Crime  en  37000000  117378084.0
#
#            Profit  AvRating      RDate     DGrossX     FGrossX     Pop  \
# 3     -11046681.0       4.2 2014-01-10  18848538.0  40104781.0  13.754
# 3     -11046681.0       4.2 2014-01-10  18848538.0  40104781.0  13.754
# 3     -11046681.0       4.2 2014-01-10  18848538.0  40104781.0  13.754
# 10     14385836.0       5.1 2013-09-27  21569509.0   1316327.0   8.666
# 16     61300835.0       7.6 2011-09-22  75605492.0  35695343.0  15.393
# ...           ...       ...        ...         ...         ...     ...
# 73039  15852177.0       4.5 2017-05-12  45852178.0  11999999.0  10.920
# 73039  15852177.0       4.5 2017-05-12  45852178.0  11999999.0  10.920
# 73243  80378084.0       7.0 2018-02-23  69179066.0  48199018.0  19.459
# 73243  80378084.0       7.0 2018-02-23  69179066.0  48199018.0  19.459
# 73243  80378084.0       7.0 2018-02-23  69179066.0  48199018.0  19.459
#
#        VoteAv  RuntimeMin  VoteCount  RelYear   Studio  NumVotes  IsProfitable
# 3         4.5        99.0      805.0   2014.0     LG/S     50352         False
# 3         4.5        99.0      805.0   2014.0     LG/S     50352         False
# 3         4.5        99.0      805.0   2014.0     LG/S     50352         False
# 10        5.4        96.0      127.0   2013.0     FoxS      8296          True
# 16        7.1       133.0     2255.0   2011.0     Sony    326657          True
# ...       ...         ...        ...      ...      ...       ...           ...
# 73039     5.3        90.0      495.0   2017.0      Fox     29997          True
# 73039     5.3        90.0      495.0   2017.0      Fox     29997          True
# 73243     6.9       100.0     2756.0   2018.0  WB (NL)    163279          True
# 73243     6.9       100.0     2756.0   2018.0  WB (NL)    163279          True
# 73243     6.9       100.0     2756.0   2018.0  WB (NL)    163279          True
#
# [2393 rows x 18 columns]

# %%
dfexplode.head()
# Out:
#                      Title     Genres  OL   PBudget      WWGross      Profit  \
# 3   The Legend of Hercules     Action  en  70000000   58953319.0 -11046681.0
# 3   The Legend of Hercules  Adventure  en  70000000   58953319.0 -11046681.0
# 3   The Legend of Hercules    Fantasy  en  70000000   58953319.0 -11046681.0
# 10           Baggage Claim     Comedy  en   8500000   22885836.0  14385836.0
# 16               Moneyball  Biography  en  50000000  111300835.0  61300835.0
#
#     AvRating      RDate     DGrossX     FGrossX     Pop  VoteAv  RuntimeMin  \
# 3        4.2 2014-01-10  18848538.0  40104781.0  13.754     4.5        99.0
# 3        4.2 2014-01-10  18848538.0  40104781.0  13.754     4.5        99.0
# 3        4.2 2014-01-10  18848538.0  40104781.0  13.754     4.5        99.0
# 10       5.1 2013-09-27  21569509.0   1316327.0   8.666     5.4        96.0
# 16       7.6 2011-09-22  75605492.0  35695343.0  15.393     7.1       133.0
#
#     VoteCount  RelYear Studio  NumVotes  IsProfitable
# 3       805.0   2014.0   LG/S     50352         False
# 3       805.0   2014.0   LG/S     50352         False
# 3       805.0   2014.0   LG/S     50352         False
# 10      127.0   2013.0   FoxS      8296          True
# 16     2255.0   2011.0   Sony    326657          True

# %% [markdown]
# # Exploring Clean Data Visually

# %%
#list to change variables around: 
# 'Profit','Pop','Genres','WWGross','AvRating','DGrossX','FGrossX','RuntimeMin','Studio','PBudget','IsProfitable'
dfexplodeexplore = dfexplode[['Profit','Pop','Genres','AvRating','WWGross', 'RelYear',
                                'RuntimeMin','Studio','IsProfitable']]
dfexplodeexplore
# Out:
#            Profit     Pop     Genres  AvRating      WWGross  RelYear  \
# 3     -11046681.0  13.754     Action       4.2   58953319.0   2014.0
# 3     -11046681.0  13.754  Adventure       4.2   58953319.0   2014.0
# 3     -11046681.0  13.754    Fantasy       4.2   58953319.0   2014.0
# 10     14385836.0   8.666     Comedy       5.1   22885836.0   2013.0
# 16     61300835.0  15.393  Biography       7.6  111300835.0   2011.0
# ...           ...     ...        ...       ...          ...      ...
# 73039  15852177.0  10.920  Adventure       4.5   57852177.0   2017.0
# 73039  15852177.0  10.920     Comedy       4.5   57852177.0   2017.0
# 73243  80378084.0  19.459     Action       7.0  117378084.0   2018.0
# 73243  80378084.0  19.459     Comedy       7.0  117378084.0   2018.0
# 73243  80378084.0  19.459      Crime       7.0  117378084.0   2018.0
#
#        RuntimeMin   Studio  IsProfitable
# 3            99.0     LG/S         False
# 3            99.0     LG/S         False
# 3            99.0     LG/S         False
# 10           96.0     FoxS          True
# 16          133.0     Sony          True
# ...           ...      ...           ...
# 73039        90.0      Fox          True
# 73039        90.0      Fox          True
# 73243       100.0  WB (NL)          True
# 73243       100.0  WB (NL)          True
# 73243       100.0  WB (NL)          True
#
# [2393 rows x 9 columns]

# %%
sns.pairplot(dfexplodeexplore, hue='IsProfitable', plot_kws={'alpha':0.3}, palette={True:'lightblue',False:'darkred'})

# %% [markdown]
# ## Just looking at negative profit

# %%
negprofit = dfexplode[dfexplode['Profit'] < 0]
negprofit.head()
# Out:
#                      Title     Genres  OL   PBudget     WWGross      Profit  \
# 3   The Legend of Hercules     Action  en  70000000  58953319.0 -11046681.0
# 3   The Legend of Hercules  Adventure  en  70000000  58953319.0 -11046681.0
# 3   The Legend of Hercules    Fantasy  en  70000000  58953319.0 -11046681.0
# 22                   Aloha     Comedy  en  37000000  25387091.0 -11612909.0
# 22                   Aloha      Drama  en  37000000  25387091.0 -11612909.0
#
#     AvRating      RDate     DGrossX     FGrossX     Pop  VoteAv  RuntimeMin  \
# 3        4.2 2014-01-10  18848538.0  40104781.0  13.754     4.5        99.0
# 3        4.2 2014-01-10  18848538.0  40104781.0  13.754     4.5        99.0
# 3        4.2 2014-01-10  18848538.0  40104781.0  13.754     4.5        99.0
# 22       5.4 2015-05-29  21052030.0   4335061.0   9.685     5.3       105.0
# 22       5.4 2015-05-29  21052030.0   4335061.0   9.685     5.3       105.0
#
#     VoteCount  RelYear Studio  NumVotes  IsProfitable
# 3       805.0   2014.0   LG/S     50352         False
# 3       805.0   2014.0   LG/S     50352         False
# 3       805.0   2014.0   LG/S     50352         False
# 22     1226.0   2015.0   Sony     54646         False
# 22     1226.0   2015.0   Sony     54646         False

# %%
negprofitexplore = negprofit[['Profit','Pop','WWGross','AvRating', 'Genres',
                                'DGrossX','FGrossX','RuntimeMin','Studio','PBudget']]

# %%
sns.pairplot(negprofitexplore)

# %% [markdown]
# ## Looking at Genres

# %%
(dfexplode[df['Genres'].str.contains('Thriller')]).sort_values(by='Profit').tail(30)
# Out:
# <ipython-input-70-4421fbe0f645>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   (dfexplode[df['Genres'].str.contains('Thriller')]).sort_values(by='Profit').tail(30)
#                          Title     Genres  OL    PBudget       WWGross  \
# 32016                  Taken 2     Action  en   45000000  3.778074e+08
# 32016                  Taken 2   Thriller  en   45000000  3.778074e+08
# 18996                     Lucy   Thriller  en   40000000  4.575078e+08
# 18996                     Lucy     Sci-Fi  en   40000000  4.575078e+08
# 18996                     Lucy     Action  en   40000000  4.575078e+08
# 37869                Fast Five      Crime  en  125000000  6.301635e+08
# 59407  6.624580e+08       7.4 2017-09-08  327481748.0  3.699762e+08  13.966
# 8749   8.094391e+08       8.4 2012-07-20  448139099.0  6.363000e+08  26.220
# 8749   8.094391e+08       8.4 2012-07-20  448139099.0  6.363000e+08  26.220
# 56918  9.105270e+08       7.8 2012-11-09  304360277.0  8.061667e+08  19.270
# 56918  9.105270e+08       7.8 2012-11-09  304360277.0  8.061667e+08  19.270
# 56918  9.105270e+08       7.8 2012-11-09  304360277.0  8.061667e+08  19.270
# 28455  9.848463e+08       6.7 2017-04-14  225764765.0  1.009082e+09  28.668
# 28455  9.848463e+08       6.7 2017-04-14  225764765.0  1.009082e+09  28.668
# 28455  9.848463e+08       6.7 2017-04-14  225764765.0  1.009082e+09  28.668
# 14229  1.328723e+09       7.2 2015-04-03  353007020.0  1.165716e+09  20.396
# 14229  1.328723e+09       7.2 2015-04-03  353007020.0  1.165716e+09  20.396
# 14229  1.328723e+09       7.2 2015-04-03  353007020.0  1.165716e+09  20.396
#
#        VoteAv  RuntimeMin  VoteCount  RelYear   Studio  NumVotes  IsProfitable
# 32016     6.2        92.0     4035.0   2012.0      Fox    273106          True
# 32016     6.2        92.0     4035.0   2012.0      Fox    273106          True
# 18996     6.3        89.0    10019.0   2014.0     Uni.    403194          True
# 18996     6.3        89.0    10019.0   2014.0     Uni.    403194          True
# 18996     6.3        89.0    10019.0   2014.0     Uni.    403194          True
# 37869     7.2       130.0     4294.0   2011.0     Uni.    329892          True
# 37869     7.2       130.0     4294.0   2011.0     Uni.    329892          True
# 37869     7.2       130.0     4294.0   2011.0     Uni.    329892          True
# 39754     5.4       125.0     6451.0   2015.0     Uni.    279126          True
# 39754     5.4       125.0     6451.0   2015.0     Uni.    279126          True
# 39754     5.4       125.0     6451.0   2015.0     Uni.    279126          True
# 51634     6.4       148.0     6719.0   2015.0     Sony    352504          True
# 51634     6.4       148.0     6719.0   2015.0     Sony    352504          True
# 51634     6.4       148.0     6719.0   2015.0     Sony    352504          True
# 52609     7.2        91.0     9586.0   2013.0       WB    710018          True
# 52609     7.2        91.0     9586.0   2013.0       WB    710018          True
# 52609     7.2        91.0     9586.0   2013.0       WB    710018          True
# 59407     7.2       135.0    10931.0   2017.0  WB (NL)    359123          True
# 59407     7.2       135.0    10931.0   2017.0  WB (NL)    359123          True
# 8749      7.7       164.0    13933.0   2012.0       WB   1387769          True
# 8749      7.7       164.0    13933.0   2012.0       WB   1387769          True
# 56918     7.1       143.0    10441.0   2012.0     Sony    592221          True
# 56918     7.1       143.0    10441.0   2012.0     Sony    592221          True
# 56918     7.1       143.0    10441.0   2012.0     Sony    592221          True
# 28455     6.9       136.0     6335.0   2017.0     Uni.    179774          True
# 28455     6.9       136.0     6335.0   2017.0     Uni.    179774          True
# 28455     6.9       136.0     6335.0   2017.0     Uni.    179774          True
# 14229     7.3       137.0     6538.0   2015.0     Uni.    335074          True
# 14229     7.3       137.0     6538.0   2015.0     Uni.    335074          True
# 14229     7.3       137.0     6538.0   2015.0     Uni.    335074          True

# %%
negprofitexploregenres = dfexplodeexploregenres[dfexplodeexploregenres['Profit'] < 0]
negprofitexploregenres.shape
# Out:
# (308, 9)

# %%
print(dfexplodeexplore['Genres'].value_counts())
# Out:
# Drama          410
# Comedy         340
# Action         305
# Adventure      269
# Thriller       160
# Crime          144
# Romance        114
# Sci-Fi          94
# Horror          88
# Biography       82
# Animation       82
# Fantasy         77
# Mystery         77
# Family          63
# Music           26
# History         26
# Sport           17
# Documentary      8
# Western          5
# War              3
# Musical          3
# Name: Genres, dtype: int64

# %%
print(dfexplodeexploregenres['Genres'].value_counts())
sns.catplot(data=dfexplodeexploregenres, x='Genres', y = 'Profit', kind='box', height=5, aspect=2)
plt.xticks(rotation=90)
plt.show()
# Out:
# Drama        410
# Comedy       340
# Action       305
# Adventure    269
# Thriller     160
# Crime        144
# Romance      114
# Sci-Fi        94
# Horror        88
# Biography     82
# Animation     82
# Fantasy       77
# Mystery       77
# Family        63
# Music         26
# History       26
# Name: Genres, dtype: int64

# %%
columns = ['Profit','Pop','WWGross','AvRating', 'RuntimeMin']
print(dfexplodeexploregenres['Genres'].value_counts())
for col in columns:
    sns.catplot(data=dfexplodeexploregenres, x='Genres', y = col, kind='box', height=5, aspect=2,)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Drama        410
# Comedy       340
# Action       305
# Adventure    269
# Thriller     160
# Crime        144
# Romance      114
# Sci-Fi        94
# Horror        88
# Biography     82
# Animation     82
# Fantasy       77
# Mystery       77
# Family        63
# Music         26
# History       26
# Name: Genres, dtype: int64

# %%
dfexplodeexplore.shape
# Out:
# (2393, 9)

# %%
columns = ['Profit','Pop','WWGross','AvRating', 'RuntimeMin','Studio']
print(negprofitexploregenres['Genres'].value_counts())
for col in columns:
    sns.catplot(data=negprofitexploregenres, x='Genres', y = col, kind='strip', height=5, aspect=2)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Drama        76
# Action       42
# Comedy       33
# Crime        30
# Adventure    23
# Thriller     19
# Biography    16
# Romance      13
# Sci-Fi       11
# Fantasy      11
# Horror        9
# Mystery       8
# Family        6
# History       5
# Animation     3
# Music         3
# Name: Genres, dtype: int64

# %%
x = dfexplodeexplore['Genres'].value_counts()
y = x[x > 20].index.tolist()
dfexplodeexploregenres = dfexplodeexplore[dfexplodeexplore['Genres'].isin(y)]
dfexplodeexploregenres.head(1)
# Out:
#        Profit     Pop  Genres  AvRating     WWGross  RelYear  RuntimeMin  \
# 3 -11046681.0  13.754  Action       4.2  58953319.0   2014.0        99.0
#
#   Studio  IsProfitable
# 3   LG/S         False

# %% [markdown]
# ## Lets make these graphs a bit more pretty

# %%
pbg = dfexplodeexploregenres.groupby('Genres')['Profit'].median().sort_values(ascending=False)
dfexplodeexploregenres['Genres'] = pd.Categorical(dfexplodeexploregenres['Genres'], categories=pbg.index, ordered=True)
pbg
# Out:
# <ipython-input-103-d3787fe67fc5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfexplodeexploregenres['Genres'] = pd.Categorical(dfexplodeexploregenres['Genres'], categories=pbg.index, ordered=True)
# Genres
# Animation    241270737.0
# Sci-Fi       167054362.0
# Adventure    161900902.0
# Action        91974557.0
# Comedy        61689649.5
# Mystery       60133905.0
# Thriller      60125202.0
# Fantasy       57422558.0
# Horror        56953436.5
# Family        55695194.0
# History       48268100.0
# Music         38914858.5
# Crime         33989778.5
# Romance       32805102.0
# Drama         29885958.0
# Biography     28913641.0
# Name: Profit, dtype: float64

# %%
dfexplodeexploregenres.groupby('Genres')['Profit'].mean().sort_values(ascending=False)
# Out:
# Genres
# Animation    3.257635e+08
# Sci-Fi       2.941252e+08
# Adventure    2.771487e+08
# Action       2.025083e+08
# Fantasy      1.755796e+08
# Comedy       1.292495e+08
# Thriller     1.191629e+08
# Family       1.113462e+08
# Music        9.697897e+07
# Mystery      8.982517e+07
# Horror       8.548539e+07
# Biography    8.012003e+07
# History      7.603357e+07
# Crime        7.181980e+07
# Drama        6.756017e+07
# Romance      6.111323e+07
# Name: Profit, dtype: float64

# %%
pbg2 = negprofitexploregenres.groupby('Genres')['Profit'].median().sort_values()
negprofitexploregenres['Genres'] = pd.Categorical(negprofitexploregenres['Genres'], categories=pbg2.index, ordered=True)
pbg2
# Out:
# Genres
# History     -20747239.0
# Fantasy     -12965385.0
# Family      -12473092.5
# Action      -10359888.0
# Biography   -10267252.5
# Drama        -9207855.5
# Thriller     -8957417.0
# Mystery      -8415085.5
# Crime        -8381399.0
# Horror       -8272530.0
# Adventure    -7634502.0
# Comedy       -6540817.0
# Animation    -4714110.0
# Music        -4221368.0
# Romance      -3924991.0
# Sci-Fi       -3826282.0
# Name: Profit, dtype: float64

# %%
sns.set_theme(style='whitegrid')

# %%
print(dfexplodeexploregenres['Genres'].value_counts())
sns.catplot(data=dfexplodeexploregenres, x='Genres', y = 'Profit', kind='box', height=5, aspect=2, palette='viridis')
plt.xticks(rotation=90)
plt.title('Best Performing Genres by Profit')
plt.show()
# Out:
# Drama        410
# Comedy       340
# Action       305
# Adventure    269
# Thriller     160
# Crime        144
# Romance      114
# Sci-Fi        94
# Horror        88
# Biography     82
# Animation     82
# Fantasy       77
# Mystery       77
# Family        63
# Music         26
# History       26
# Name: Genres, dtype: int64

# %%
print(negprofitexploregenres['Genres'].value_counts())
sns.catplot(data=negprofitexploregenres, x='Genres', y = 'Profit', kind='swarm', height=5, aspect=2)
plt.title('Unprofitable Genres')
plt.xticks(rotation=90)
plt.show()
# Out:
# Drama        76
# Action       42
# Comedy       33
# Crime        30
# Adventure    23
# Thriller     19
# Biography    16
# Romance      13
# Sci-Fi       11
# Fantasy      11
# Horror        9
# Mystery       8
# Family        6
# History       5
# Music         3
# Animation     3
# Name: Genres, dtype: int64
# /Users/jamiecarnevale/miniconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/jamiecarnevale/miniconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Creating a Graph that tests the Proportionality between Profitable Films and Unprofitable Films by Genre

# %%
#percent of IsProfitable False / IsProfitable.valuecount

# %%
dfexplodeexploregenres.groupby('Genres')['IsProfitable'].count()
# Out:
# Genres
# Animation     82
# Sci-Fi        94
# Adventure    269
# Action       305
# Comedy       340
# Mystery       77
# Thriller     160
# Fantasy       77
# Horror        88
# Family        63
# History       26
# Music         26
# Crime        144
# Romance      114
# Drama        410
# Biography     82
# Name: IsProfitable, dtype: int64

# %%
x = dfexplodeexplore['Genres'].value_counts()

# %%
x = dfexplodeexploregenres.groupby('Genres')['IsProfitable'].count().sort_values(ascending=False)
y = dfexplodeexploregenres.groupby('Genres')['IsProfitable'].sum().sort_values(ascending=False)
z = (x-y)/x
percentprofit = z.reset_index()
percentprofit.columns = ['Genre', 'PercentNotProfitable']
percentprofit['PercentNotProfitable'] = percentprofit['PercentNotProfitable'] * 100
percentprofit = percentprofit.sort_values(by='PercentNotProfitable', ascending=False)
percentprofit
# Out:
#         Genre  PercentNotProfitable
# 12      Crime             20.833333
# 15  Biography             19.512195
# 10    History             19.230769
# 14      Drama             18.536585
# 7     Fantasy             14.285714
# 3      Action             13.770492
# 6    Thriller             11.875000
# 1      Sci-Fi             11.702128
# 11      Music             11.538462
# 13    Romance             11.403509
# 5     Mystery             10.389610
# 8      Horror             10.227273
# 4      Comedy              9.705882
# 9      Family              9.523810
# 2   Adventure              8.550186
# 0   Animation              3.658537

# %%
fig, ax =plt.subplots(figsize=(16, 10))
sns.barplot(data=percentprofit, x='Genre', y='PercentNotProfitable', order=percentprofit['Genre'], palette='viridis',ax=ax)
print(dfexplodeexploregenres.groupby('Genres')['IsProfitable'].count())
ax.set_title('Percent of Financially Draining Films by Genre')
plt.xticks(rotation=90)
plt.show()
# Out:
# Genres
# Animation     82
# Sci-Fi        94
# Adventure    269
# Action       305
# Comedy       340
# Mystery       77
# Thriller     160
# Fantasy       77
# Horror        88
# Family        63
# History       26
# Music         26
# Crime        144
# Romance      114
# Drama        410
# Biography     82
# Name: IsProfitable, dtype: int64

# %%
dfexplodeexploregenres
# Out:
#            Profit     Pop     Genres  AvRating      WWGross  RelYear  \
# 3     -11046681.0  13.754     Action       4.2   58953319.0   2014.0
# 3     -11046681.0  13.754  Adventure       4.2   58953319.0   2014.0
# 3     -11046681.0  13.754    Fantasy       4.2   58953319.0   2014.0
# 10     14385836.0   8.666     Comedy       5.1   22885836.0   2013.0
# 16     61300835.0  15.393  Biography       7.6  111300835.0   2011.0
# ...           ...     ...        ...       ...          ...      ...
# 73039  15852177.0  10.920  Adventure       4.5   57852177.0   2017.0
# 73039  15852177.0  10.920     Comedy       4.5   57852177.0   2017.0
# 73243  80378084.0  19.459     Action       7.0  117378084.0   2018.0
# 73243  80378084.0  19.459     Comedy       7.0  117378084.0   2018.0
# 73243  80378084.0  19.459      Crime       7.0  117378084.0   2018.0
#
#        RuntimeMin   Studio  IsProfitable
# 3            99.0     LG/S         False
# 3            99.0     LG/S         False
# 3            99.0     LG/S         False
# 10           96.0     FoxS          True
# 16          133.0     Sony          True
# ...           ...      ...           ...
# 73039        90.0      Fox          True
# 73039        90.0      Fox          True
# 73243       100.0  WB (NL)          True
# 73243       100.0  WB (NL)          True
# 73243       100.0  WB (NL)          True
#
# [2357 rows x 9 columns]

# %%
sns.
